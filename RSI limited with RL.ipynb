# %%
import gym
from gym import spaces
import numpy as np
import pandas as pd

class TradingEnv(gym.Env):
    def __init__(self):
        super(TradingEnv, self).__init__()

        # Load the CSV file with trading data
        self.data = pd.read_csv("C:\\Users\\Yash\\Downloads\\tata.csv")

        # Define the action space
        self.action_space = spaces.MultiDiscrete([3, 100])  # 3 actions: 0 (sell), 1 (hold), 2 (buy), with quantity 0-100

        # Define the observation space
        self.observation_space = spaces.Box(low=0, high=1, shape=(45, len(self.data.columns) - 1), dtype=np.float32)

        # Initialize other parameters
        self.balance = 100000
        self.shares_held = 0
        self.current_step = 45  # Start from the 45th candle
        self.reward_range = (-np.inf, np.inf)
        self.current_charge = 0
        self.profit = 0

    def reset(self):
        # Reset the environment to the initial state
        self.balance = 100000
        self.shares_held = 0
        self.current_step = 45  # Start from the 45th candle
        self.current_charge = 0
        self.profit = 0

        # Get the initial observation
        observation = self.get_observation()
        return observation

    def step(self, action):
        # Execute the selected action
        if action[0] == 0:  # Sell
            if self.shares_held >= action[1]:
                self.balance += action[1] * self.data.iloc[self.current_step]['Close']
                self.shares_held -= action[1]
                self.current_charge += 20
            else:
                return self.get_observation(), -10, True, {}

        elif action[0] == 2:  # Buy
            if self.balance >= action[1] * self.data.iloc[self.current_step]['Close']:
                self.balance -= action[1] * self.data.iloc[self.current_step]['Close']
                self.shares_held += action[1]
                self.current_charge += 100

        # Deduct charge every 90th candle
        if self.current_step % 90 == 0:
            self.balance -= 100

        # Check RSI condition
        if self.data.iloc[self.current_step]['RSI'] > 45 and action[0] == 2:  # Don't buy if RSI > 45
            return self.get_observation(), -5, True, {}

        # Update the current step
        self.current_step += 1

        # Calculate the reward
        reward = self.calculate_reward()

        # Check if the episode is done
        done = self.current_step == len(self.data) - 1 or self.balance <= 0

        return self.get_observation(), reward, done, {}

    def get_observation(self):
        # Get the current observation (past 45 candle data)
        observation = self.data.iloc[self.current_step - 45:self.current_step, :-1].values
        return observation

    def calculate_reward(self):
        # Calculate the reward based on profit/loss
        current_value = self.balance + self.shares_held * self.data.iloc[self.current_step]['Close']
        reward = current_value - 100000 - self.current_charge
        return reward

    def render(self):
        # Display current balance and shares held
        print(f"Balance: {self.balance}, Shares Held: {self.shares_held}")

# Test the environment
if __name__ == "__main__":
    env = TradingEnv()
    observation = env.reset()
    done = False
    while not done:
        action = env.action_space.sample()  # Random action for testing
        observation, reward, done, _ = env.step(action)
        env.render()
# Out:
# Balance: 100000, Shares Held: 0
# Balance: 99340.91382029, Shares Held: 70

# %%
MultiDiscrete([3, 100])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 MultiDiscrete([3, 100])
#
# NameError: name 'MultiDiscrete' is not defined

# %%
import gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv


# Import your custom TradingEnv (update the import statement if needed)
# from trading_env import TradingEnv  # Make sure to replace 'trading_env' with your file name

# Create a function to evaluate the trained model
def evaluate_trained_model(model, env, num_episodes=10):
    mean_rewards, std_rewards = evaluate_policy(model, env, n_eval_episodes=num_episodes)
    return mean_rewards, std_rewards

# Create and wrap the custom environment
env = TradingEnv()
env = DummyVecEnv([lambda: env])

# Create the PPO agent
model = PPO("MlpPolicy", env, verbose=1)

# Train the model (you can adjust the number of training steps)
model.learn(total_timesteps=1000000)

# Evaluate the trained model
mean_rewards, std_rewards = evaluate_trained_model(model, env)

print(f"Mean Reward: {mean_rewards:.2f}, Std Reward: {std_rewards:.2f}")

# Test the model for a few episodes
for _ in range(5):
    obs = env.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, _ = env.step(action)
        total_reward += reward
        env.render()
    print(f"Episode Reward: {total_reward:.2f}")
# Out:
# C:\Users\Yash\AppData\Roaming\Python\Python310\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 833  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 654        |
# |    iterations           | 2          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.19097495 |
# |    clip_fraction        | 0.69       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.6       |
# |    explained_variance   | -0.0082    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.05       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.121     |
# |    value_loss           | 30.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 609        |
# |    iterations           | 3          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.20952234 |
# |    clip_fraction        | 0.598      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.3       |
# |    explained_variance   | 0.00131    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.61       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.105     |
# |    value_loss           | 4.11       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.020720633 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | -0.00769    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00837    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 0.612       |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 580       |
# |    iterations           | 5         |
# |    time_elapsed         | 17        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0722488 |
# |    clip_fraction        | 0.692     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.26     |
# |    explained_variance   | -0.0224   |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.109    |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -0.0716   |
# |    value_loss           | 0.142     |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 578        |
# |    iterations           | 6          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.04182916 |
# |    clip_fraction        | 0.828      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.23      |
# |    explained_variance   | -0.0114    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.142     |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.075     |
# |    value_loss           | 0.217      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 576         |
# |    iterations           | 7           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.031154942 |
# |    clip_fraction        | 0.618       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.18       |
# |    explained_variance   | -0.000289   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0535     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0507     |
# |    value_loss           | 0.326       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 576         |
# |    iterations           | 8           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.030440731 |
# |    clip_fraction        | 0.502       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | -0.00282    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0821     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0524     |
# |    value_loss           | 0.22        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 576         |
# |    iterations           | 9           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.047518045 |
# |    clip_fraction        | 0.506       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.98       |
# |    explained_variance   | 0.0136      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.097      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0492     |
# |    value_loss           | 0.287       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 10          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.035531126 |
# |    clip_fraction        | 0.44        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.87       |
# |    explained_variance   | -0.0286     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0501     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0557     |
# |    value_loss           | 0.129       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 11          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.057422653 |
# |    clip_fraction        | 0.433       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.78       |
# |    explained_variance   | -0.00622    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0673      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0598     |
# |    value_loss           | 0.151       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 12          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.033192158 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.72       |
# |    explained_variance   | 0.0135      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0214      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0401     |
# |    value_loss           | 0.366       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 578           |
# |    iterations           | 13            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00014299608 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.77         |
# |    explained_variance   | -0.000384     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.35e+04      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000482     |
# |    value_loss           | 4.73e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 14           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 9.799466e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.77        |
# |    explained_variance   | 4.21e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.09e+04     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000808    |
# |    value_loss           | 8.16e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 15           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0008974789 |
# |    clip_fraction        | 0.00151      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.78        |
# |    explained_variance   | 0.000739     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.96e+04     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 2.54e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 16          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004427271 |
# |    clip_fraction        | 0.0236      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.79       |
# |    explained_variance   | -0.00218    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.58e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000948   |
# |    value_loss           | 7e+04       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 578        |
# |    iterations           | 17         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.04065626 |
# |    clip_fraction        | 0.316      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.85      |
# |    explained_variance   | -0.128     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.51       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0593    |
# |    value_loss           | 1.6        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 18          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.020850029 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.78       |
# |    explained_variance   | -0.0806     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0575     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0422     |
# |    value_loss           | 0.194       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 19          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.023633972 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.71       |
# |    explained_variance   | 0.0292      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.288       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0401     |
# |    value_loss           | 0.268       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 20          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.028141074 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.66       |
# |    explained_variance   | 0.00648     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.033      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0526     |
# |    value_loss           | 0.0895      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 21          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.026792783 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.63       |
# |    explained_variance   | 0.0172      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0189      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0466     |
# |    value_loss           | 0.261       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 22          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.029661784 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.58       |
# |    explained_variance   | -0.0389     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0224      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0607     |
# |    value_loss           | 0.131       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 580           |
# |    iterations           | 23            |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00022344137 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.62         |
# |    explained_variance   | 0.000414      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.32e+04      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -7.58e-05     |
# |    value_loss           | 1.14e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 24           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 2.876157e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.63        |
# |    explained_variance   | 0.000672     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.79e+05     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000259    |
# |    value_loss           | 6.38e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 580           |
# |    iterations           | 25            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 3.6230485e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.62         |
# |    explained_variance   | 0.00236       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.45e+04      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000239     |
# |    value_loss           | 2.12e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 580           |
# |    iterations           | 26            |
# |    time_elapsed         | 91            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 3.2968237e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.62         |
# |    explained_variance   | 0.00203       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.65e+03      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000681     |
# |    value_loss           | 1.01e+05      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 27          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 9.28808e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.63       |
# |    explained_variance   | 0.007       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35e+05    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000402   |
# |    value_loss           | 1.88e+05    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 580           |
# |    iterations           | 28            |
# |    time_elapsed         | 98            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 1.7704093e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.63         |
# |    explained_variance   | 0.00631       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.8e+04       |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000515     |
# |    value_loss           | 1.61e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 580           |
# |    iterations           | 29            |
# |    time_elapsed         | 102           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 1.7109676e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.63         |
# |    explained_variance   | 0.00498       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.15e+05      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000492     |
# |    value_loss           | 3.31e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 30           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 5.465059e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.63        |
# |    explained_variance   | 0.00235      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.69e+04     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000988    |
# |    value_loss           | 2.63e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 580           |
# |    iterations           | 31            |
# |    time_elapsed         | 109           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00025668213 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.64         |
# |    explained_variance   | 0.0127        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.44e+04      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.00176      |
# |    value_loss           | 8.58e+04      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 32          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.016067572 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.66       |
# |    explained_variance   | -0.546      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 119         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 446         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 580        |
# |    iterations           | 33         |
# |    time_elapsed         | 116        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.05230782 |
# |    clip_fraction        | 0.289      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.73      |
# |    explained_variance   | -0.293     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.4        |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0571    |
# |    value_loss           | 25         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 34          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.056339458 |
# |    clip_fraction        | 0.38        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.66       |
# |    explained_variance   | -7.16       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00689    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.065      |
# |    value_loss           | 0.795       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 35          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.020256128 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.56       |
# |    explained_variance   | -0.388      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0713     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0433     |
# |    value_loss           | 0.31        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 580        |
# |    iterations           | 36         |
# |    time_elapsed         | 126        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.02047662 |
# |    clip_fraction        | 0.231      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.53      |
# |    explained_variance   | 0.00434    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.575      |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0282    |
# |    value_loss           | 5.29       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 37          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.022735387 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 0.029       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.388       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0358     |
# |    value_loss           | 0.429       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 38          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.023126598 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | 0.0322      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.342       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0361     |
# |    value_loss           | 0.5         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 580        |
# |    iterations           | 39         |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.02656513 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.47      |
# |    explained_variance   | 0.0202     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0639    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0484    |
# |    value_loss           | 0.0869     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 40           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0021127989 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.49        |
# |    explained_variance   | 0.00789      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.52e+03     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.00161      |
# |    value_loss           | 8.58e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 41          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.012108572 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | -2.6        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.23        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0259     |
# |    value_loss           | 11.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 42          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.026434347 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | -2.69       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.128       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0474     |
# |    value_loss           | 0.612       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 43          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.027543746 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.37       |
# |    explained_variance   | -0.343      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0943     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0521     |
# |    value_loss           | 0.0849      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 44          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.021753075 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.00777     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0589      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0368     |
# |    value_loss           | 0.412       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 581           |
# |    iterations           | 45            |
# |    time_elapsed         | 158           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00038129362 |
# |    clip_fraction        | 0.000488      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.32         |
# |    explained_variance   | -0.00327      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 292           |
# |    n_updates            | 440           |
# |    policy_gradient_loss | 0.00019       |
# |    value_loss           | 1.11e+05      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 46          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.019200068 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | -4.5        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.129       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0453     |
# |    value_loss           | 2.08        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 47          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.020985939 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | -0.0222     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0831      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0389     |
# |    value_loss           | 0.448       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 48           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0009397451 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | -0.00142     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19e+03     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 1e+03        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 581           |
# |    iterations           | 49            |
# |    time_elapsed         | 172           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 9.5780415e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.24         |
# |    explained_variance   | 0.027         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.1e+04       |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000318     |
# |    value_loss           | 9.33e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 581           |
# |    iterations           | 50            |
# |    time_elapsed         | 176           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 1.3126351e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.25         |
# |    explained_variance   | 0.0506        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.3e+04       |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.00044      |
# |    value_loss           | 5.64e+04      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 51          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.004796914 |
# |    clip_fraction        | 0.029       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | -1.41       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.4        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 72.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 52          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.023958853 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | -5.03       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.74        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0433     |
# |    value_loss           | 3.42        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 581        |
# |    iterations           | 53         |
# |    time_elapsed         | 186        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.02583535 |
# |    clip_fraction        | 0.28       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.2       |
# |    explained_variance   | -0.809     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0961     |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0551    |
# |    value_loss           | 0.435      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 54          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.026215259 |
# |    clip_fraction        | 0.337       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.625       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.035      |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0609     |
# |    value_loss           | 0.0027      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 55          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.024653595 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0864     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0475     |
# |    value_loss           | 0.0704      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 56           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0063305004 |
# |    clip_fraction        | 0.0611       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.18        |
# |    explained_variance   | -0.00133     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.38e+04     |
# |    n_updates            | 550          |
# |    policy_gradient_loss | 6.62e-05     |
# |    value_loss           | 1.4e+05      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 57           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 2.052082e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.2         |
# |    explained_variance   | 0.0316       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.48e+04     |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.000372    |
# |    value_loss           | 2.68e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 580           |
# |    iterations           | 58            |
# |    time_elapsed         | 204           |
# |    total_timesteps      | 118784        |
# | train/                  |               |
# |    approx_kl            | 7.0673705e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.2          |
# |    explained_variance   | 0.0829        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.36e+04      |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -0.000369     |
# |    value_loss           | 5.85e+04      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 59          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.008494614 |
# |    clip_fraction        | 0.0528      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | -2.72       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.82        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 45.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 580          |
# |    iterations           | 60           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0048556924 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.18        |
# |    explained_variance   | 0.464        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.472        |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.0109      |
# |    value_loss           | 100          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 580        |
# |    iterations           | 61         |
# |    time_elapsed         | 215        |
# |    total_timesteps      | 124928     |
# | train/                  |            |
# |    approx_kl            | 0.03172509 |
# |    clip_fraction        | 0.344      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.09      |
# |    explained_variance   | -105       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.103     |
# |    n_updates            | 600        |
# |    policy_gradient_loss | -0.0669    |
# |    value_loss           | 0.0558     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 62          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.017985176 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | -0.658      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.171       |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0318     |
# |    value_loss           | 0.375       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 63          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.021864979 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0649      |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0324     |
# |    value_loss           | 0.175       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 580          |
# ...
# |    loss                 | 9.88e+03      |
# |    n_updates            | 4690          |
# |    policy_gradient_loss | -0.000226     |
# |    value_loss           | 4.62e+04      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 471         |
# |    time_elapsed         | 1685        |
# |    total_timesteps      | 964608      |
# | train/                  |             |
# |    approx_kl            | 0.022834547 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | -3.61       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.108       |
# |    n_updates            | 4700        |
# |    policy_gradient_loss | -0.0261     |
# |    value_loss           | 10          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 472          |
# |    time_elapsed         | 1688         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0028446545 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | -27.9        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.5         |
# |    n_updates            | 4710         |
# |    policy_gradient_loss | -0.00484     |
# |    value_loss           | 2.58e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 572           |
# |    iterations           | 473           |
# |    time_elapsed         | 1692          |
# |    total_timesteps      | 968704        |
# | train/                  |               |
# |    approx_kl            | 2.5184156e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.599         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.64e+05      |
# |    n_updates            | 4720          |
# |    policy_gradient_loss | 0.00014       |
# |    value_loss           | 4.49e+05      |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 572            |
# |    iterations           | 474            |
# |    time_elapsed         | 1695           |
# |    total_timesteps      | 970752         |
# | train/                  |                |
# |    approx_kl            | 1.02154445e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.94          |
# |    explained_variance   | 0.382          |
# |    learning_rate        | 0.0003         |
# |    loss                 | 6.84e+05       |
# |    n_updates            | 4730           |
# |    policy_gradient_loss | -5.74e-05      |
# |    value_loss           | 1.63e+06       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 572           |
# |    iterations           | 475           |
# |    time_elapsed         | 1699          |
# |    total_timesteps      | 972800        |
# | train/                  |               |
# |    approx_kl            | 1.4260877e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.04         |
# |    explained_variance   | 0.13          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.17e+07      |
# |    n_updates            | 4740          |
# |    policy_gradient_loss | -1.1e-05      |
# |    value_loss           | 4.51e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 476          |
# |    time_elapsed         | 1703         |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 0.0007686764 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | -3.45        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.7         |
# |    n_updates            | 4750         |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 4.07e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 572           |
# |    iterations           | 477           |
# |    time_elapsed         | 1706          |
# |    total_timesteps      | 976896        |
# | train/                  |               |
# |    approx_kl            | 1.7306214e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.82         |
# |    explained_variance   | 0.721         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2e+04         |
# |    n_updates            | 4760          |
# |    policy_gradient_loss | -0.000438     |
# |    value_loss           | 9.57e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 478          |
# |    time_elapsed         | 1710         |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0046845926 |
# |    clip_fraction        | 0.00967      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | -20.4        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.7         |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | -0.00614     |
# |    value_loss           | 1.67e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 479          |
# |    time_elapsed         | 1713         |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 8.868636e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.02        |
# |    explained_variance   | 0.172        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.13e+06     |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | -0.000131    |
# |    value_loss           | 2e+07        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 480          |
# |    time_elapsed         | 1717         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0015822408 |
# |    clip_fraction        | 0.00366      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.79        |
# |    explained_variance   | -4.83        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.5         |
# |    n_updates            | 4790         |
# |    policy_gradient_loss | -0.00325     |
# |    value_loss           | 2.6e+03      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 481          |
# |    time_elapsed         | 1721         |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 3.945132e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.3          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.62e+06     |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | 2.55e-05     |
# |    value_loss           | 3.79e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 572           |
# |    iterations           | 482           |
# |    time_elapsed         | 1724          |
# |    total_timesteps      | 987136        |
# | train/                  |               |
# |    approx_kl            | 0.00039509445 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.82         |
# |    explained_variance   | 0.803         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.26e+03      |
# |    n_updates            | 4810          |
# |    policy_gradient_loss | -0.00292      |
# |    value_loss           | 1.69e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 572           |
# |    iterations           | 483           |
# |    time_elapsed         | 1728          |
# |    total_timesteps      | 989184        |
# | train/                  |               |
# |    approx_kl            | 0.00072489673 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.82         |
# |    explained_variance   | 0.745         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.78e+04      |
# |    n_updates            | 4820          |
# |    policy_gradient_loss | -0.00318      |
# |    value_loss           | 3.56e+04      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 484         |
# |    time_elapsed         | 1731        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.036790654 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | -39.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.8        |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 48.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 485         |
# |    time_elapsed         | 1735        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.014150651 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | -27.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 109         |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 1.43e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 572        |
# |    iterations           | 486        |
# |    time_elapsed         | 1739       |
# |    total_timesteps      | 995328     |
# | train/                  |            |
# |    approx_kl            | 0.07381343 |
# |    clip_fraction        | 0.298      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.84      |
# |    explained_variance   | -162       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0362     |
# |    n_updates            | 4850       |
# |    policy_gradient_loss | -0.0284    |
# |    value_loss           | 2.98       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 572        |
# |    iterations           | 487        |
# |    time_elapsed         | 1742       |
# |    total_timesteps      | 997376     |
# | train/                  |            |
# |    approx_kl            | 0.04195126 |
# |    clip_fraction        | 0.256      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.87      |
# |    explained_variance   | -10.5      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.066      |
# |    n_updates            | 4860       |
# |    policy_gradient_loss | -0.0182    |
# |    value_loss           | 0.244      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 488         |
# |    time_elapsed         | 1746        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.028304616 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | -2.84       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0151      |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.0371     |
# |    value_loss           | 0.125       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 489         |
# |    time_elapsed         | 1749        |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.018976595 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | -0.372      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0929      |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 0.185       |
# -----------------------------------------
# Mean Reward: -5.00, Std Reward: 0.00
# C:\Users\Yash\AppData\Roaming\Python\Python310\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# C:\Users\Yash\AppData\Roaming\Python\Python310\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:234: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 41
#      39     total_reward += reward
#      40     env.render()
# ---> 41 print(f"Episode Reward: {total_reward:.2f}")
#
# TypeError: unsupported format string passed to numpy.ndarray.__format__

# %%
pip install stable-baselines3[extra]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stable-baselines3[extra] in c:\users\yash\appdata\roaming\python\python310\site-packages (2.1.0)
# Requirement already satisfied: numpy>=1.20 in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.23.5)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\yash\appdata\roaming\python\python310\site-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: torch>=1.13 in c:\users\yash\appdata\roaming\python\python310\site-packages (from stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.5.3)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.7.0)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (9.4.0)
# Requirement already satisfied: pygame in c:\users\yash\appdata\roaming\python\python310\site-packages (from stable-baselines3[extra]) (2.5.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.64.1)
# Requirement already satisfied: opencv-python in c:\users\yash\appdata\roaming\python\python310\site-packages (from stable-baselines3[extra]) (4.8.0.76)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\yash\appdata\roaming\python\python310\site-packages (from stable-baselines3[extra]) (2.13.0)
# Requirement already satisfied: shimmy[atari]~=1.1.0 in c:\users\yash\appdata\roaming\python\python310\site-packages (from stable-baselines3[extra]) (1.1.0)
# Requirement already satisfied: rich in c:\users\yash\appdata\roaming\python\python310\site-packages (from stable-baselines3[extra]) (13.5.2)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.1 in c:\users\yash\appdata\roaming\python\python310\site-packages (from stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (8.0.4)
# Requirement already satisfied: requests in c:\users\yash\appdata\roaming\python\python310\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.28.1)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\yash\appdata\roaming\python\python310\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\programdata\anaconda3\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.4.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\yash\appdata\roaming\python\python310\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: ale-py~=0.8.1 in c:\users\yash\appdata\roaming\python\python310\site-packages (from shimmy[atari]~=1.1.0->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\yash\appdata\roaming\python\python310\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\yash\appdata\roaming\python\python310\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.24.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (65.6.3)
# Requirement already satisfied: wheel>=0.26 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.38.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\yash\appdata\roaming\python\python310\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\yash\appdata\roaming\python\python310\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.22.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.1)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\yash\appdata\roaming\python\python310\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.57.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\yash\appdata\roaming\python\python310\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (1.11.1)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (2.8.4)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (22.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2022.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\yash\appdata\roaming\python\python310\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\yash\appdata\roaming\python\python310\site-packages (from rich->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: importlib-resources in c:\users\yash\appdata\roaming\python\python310\site-packages (from ale-py~=0.8.1->shimmy[atari]~=1.1.0->stable-baselines3[extra]) (6.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: urllib3<2.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.26.14)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\yash\appdata\roaming\python\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: six>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\yash\appdata\roaming\python\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\yash\appdata\roaming\python\python310\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\yash\appdata\roaming\python\python310\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\yash\appdata\roaming\python\python310\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\yash\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\yash\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\yash\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\yash\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\yash\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\yash\appdata\roaming\python\python310\site-packages)
